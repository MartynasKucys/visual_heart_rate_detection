# %%
import pickle 
import matplotlib.pyplot as plt
import numpy as np

# %%
with open("data.p", "rb") as f:
    data = pickle.load(f)
with open("times.p", "rb") as f:
    times = pickle.load(f)

# %%
# new_data = list()
# std = np.std(data)
# mean = np.average(data)
# for i in range(len(data)):
#     if np.abs(data[i] - mean) > std:
#         new_data.append(data[i])
# data = new_data

# %%
# new_data = list()
# new_times = list()
# for i in range(1, len(data)-1):
#     new_data.append(np.average(np.sum([data[i-1], data[i], data[i+1]])))
#     new_times.append(times[i])
# data = new_data
# times = new_times

# %%
plt.plot(times, data)

# %%
a = np.array([0.,  0.5, 1. , 1.5])
b = np.array([120.54888523 ,368.60177763 ,349.31129864, 148.15278936])

np.sum(a * b) / np.sum(b) * 60
# Out:
# 45.96574524166546
